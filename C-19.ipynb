# %% [markdown]
# # Exploratory data analysis on COVID-19 datasets

# %%
import pandas as pd 
import numpy as np

# %%
data=pd.read_csv("CovidData.csv")
data.head(5)
# Out:
#    USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE   DATE_DIED  INTUBED  PNEUMONIA  \
# 0      2             1    1             1  03/05/2020       97          1
# 1      2             1    2             1  03/06/2020       97          1
# 2      2             1    2             2  09/06/2020        1          2
# 3      2             1    1             1  12/06/2020       97          2
# 4      2             1    2             1  21/06/2020       97          2
#
#    AGE  PREGNANT  DIABETES  ...  ASTHMA  INMSUPR  HIPERTENSION  OTHER_DISEASE  \
# 0   65         2         2  ...       2        2             1              2
# 1   72        97         2  ...       2        2             1              2
# 2   55        97         1  ...       2        2             2              2
# 3   53         2         2  ...       2        2             2              2
# 4   68        97         1  ...       2        2             1              2
#
# ...

# %%
data.tail(5)
# Out:
#          USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE   DATE_DIED  INTUBED  \
# 1048570      2            13    2             1  9999-99-99       97
# 1048571      1            13    2             2  9999-99-99        2
# 1048572      2            13    2             1  9999-99-99       97
# 1048573      2            13    2             1  9999-99-99       97
# 1048574      2            13    2             1  9999-99-99       97
#
#          PNEUMONIA  AGE  PREGNANT  DIABETES  ...  ASTHMA  INMSUPR  \
# 1048570          2   40        97         2  ...       2        2
# 1048571          2   51        97         2  ...       2        2
# 1048572          2   55        97         2  ...       2        2
# 1048573          2   28        97         2  ...       2        2
# 1048574          2   52        97         2  ...       2        2
#
#          HIPERTENSION  OTHER_DISEASE  CARDIOVASCULAR  OBESITY  RENAL_CHRONIC  \
# ...

# %%
data.shape
# Out:
# (1048575, 21)

# %%
data.dtypes
# Out:
# USMER                    int64
# MEDICAL_UNIT             int64
# SEX                      int64
# PATIENT_TYPE             int64
# DATE_DIED               object
# INTUBED                  int64
# PNEUMONIA                int64
# AGE                      int64
# PREGNANT                 int64
# DIABETES                 int64
# COPD                     int64
# ASTHMA                   int64
# INMSUPR                  int64
# HIPERTENSION             int64
# OTHER_DISEASE            int64
# CARDIOVASCULAR           int64
# OBESITY                  int64
# RENAL_CHRONIC            int64
# TOBACCO                  int64
# CLASIFFICATION_FINAL     int64
# ICU                      int64
# dtype: object

# %%
# Convert data column to datetime columns
data['DATE_DIED'] = pd.to_datetime(data['DATE_DIED'], errors='coerce', dayfirst=True)

# %%
data.dtypes
# Out:
# USMER                            int64
# MEDICAL_UNIT                     int64
# SEX                              int64
# PATIENT_TYPE                     int64
# DATE_DIED               datetime64[ns]
# INTUBED                          int64
# PNEUMONIA                        int64
# AGE                              int64
# PREGNANT                         int64
# DIABETES                         int64
# COPD                             int64
# ASTHMA                           int64
# INMSUPR                          int64
# HIPERTENSION                     int64
# OTHER_DISEASE                    int64
# CARDIOVASCULAR                   int64
# OBESITY                          int64
# RENAL_CHRONIC                    int64
# TOBACCO                          int64
# CLASIFFICATION_FINAL             int64
# ICU                              int64
# dtype: object

# %%
#data['DATE_DIED']= data['DATE_DIED'].astype('category')
# We can datatypes all the times

# %%
# Dupliates
data.duplicated().sum()
# Out:
# 812049

# %%
data[data.duplicated()]
# Out:
#          USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE DATE_DIED  INTUBED  PNEUMONIA  \
# 19           2             1    1             1       NaT       97          2
# 35           2             1    2             1       NaT       97          2
# 62           2             1    1             2       NaT        2          2
# 63           2             1    2             1       NaT       97          2
# 75           2             1    1             1       NaT       97          2
# ...        ...           ...  ...           ...       ...      ...        ...
# 1048556      2            13    2             1       NaT       97          2
# 1048558      1            13    2             1       NaT       97          2
# 1048566      2            13    2             1       NaT       97          2
# 1048570      2            13    2             1       NaT       97          2
# 1048573      2            13    2             1       NaT       97          2
#
# ...

# %%
data_cleaned= data.drop_duplicates()
data_cleaned.duplicated().sum()
# Out:
# 0

# %%
data_cleaned1=data_cleaned.drop('USMER',axis=1)
data_cleaned1.shape
# Out:
# (236526, 20)

# %%
#Rename the columns
data_cleaned2=data_cleaned.rename({'MEDICAL_UNIT':'MEDICALUNIT','PATIENT_TYPE':'PATIENTTYPE'},axis=1)
data_cleaned2.head(5)
# Out:
#    USMER  MEDICALUNIT  SEX  PATIENTTYPE  DATE_DIED  INTUBED  PNEUMONIA  AGE  \
# 0      2            1    1            1 2020-05-03       97          1   65
# 1      2            1    2            1 2020-06-03       97          1   72
# 2      2            1    2            2 2020-06-09        1          2   55
# 3      2            1    1            1 2020-06-12       97          2   53
# 4      2            1    2            1 2020-06-21       97          2   68
#
#    PREGNANT  DIABETES  ...  ASTHMA  INMSUPR  HIPERTENSION  OTHER_DISEASE  \
# 0         2         2  ...       2        2             1              2
# 1        97         2  ...       2        2             1              2
# 2        97         1  ...       2        2             2              2
# 3         2         2  ...       2        2             2              2
# 4        97         1  ...       2        2             1              2
#
# ...

# %% [markdown]
# #Outliers Detection

# %%
data_cleaned2['AGE'].hist()
# Out:
# <Axes: >

# %%
#Box Plot #Multiple fields
data_cleaned2.boxplot(column=['AGE','ASTHMA','INMSUPR','HIPERTENSION','TOBACCO'])
# Out:
# <Axes: >

# %%
data_cleaned2.describe()
# Out:
#                USMER    MEDICALUNIT            SEX    PATIENTTYPE  \
# count  236526.000000  236526.000000  236526.000000  236526.000000
# mean        1.512337       7.634230       1.547521       1.577712
# min         1.000000       1.000000       1.000000       1.000000
# 25%         1.000000       4.000000       1.000000       1.000000
# 50%         2.000000       6.000000       2.000000       2.000000
# 75%         2.000000      12.000000       2.000000       2.000000
# max         2.000000      13.000000       2.000000       2.000000
# std         0.499849       3.661318       0.497738       0.493925
#
#                            DATE_DIED        INTUBED      PNEUMONIA  \
# count                          75965  236526.000000  236526.000000
# mean   2020-06-09 14:35:11.045876224      44.238401       4.525765
# min              2020-01-02 00:00:00       1.000000       1.000000
# 25%              2020-05-18 00:00:00       2.000000       1.000000
# ...

# %%
data_cleaned2['ASTHMA'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='ASTHMA'>

# %%
#Missing values and Imputations
import seaborn as sns 
cols=data_cleaned2.columns
#colours=['#000099','#ffff00']
sns.heatmap(data_cleaned2[cols].isnull(),
cmap=sns.color_palette(colours))
# Out:
# <Axes: >

# %%
Mean=data_cleaned2['AGE'].mean()
print(Mean)
# Out:
# 52.62027430388203

# %%
data_cleaned.isnull().sum()
# Out:
# USMER                        0
# MEDICAL_UNIT                 0
# SEX                          0
# PATIENT_TYPE                 0
# DATE_DIED               160561
# INTUBED                      0
# PNEUMONIA                    0
# AGE                          0
# PREGNANT                     0
# DIABETES                     0
# COPD                         0
# ASTHMA                       0
# INMSUPR                      0
# HIPERTENSION                 0
# OTHER_DISEASE                0
# CARDIOVASCULAR               0
# OBESITY                      0
# RENAL_CHRONIC                0
# TOBACCO                      0
# CLASIFFICATION_FINAL         0
# ICU                          0
# dtype: int64
